# %%
import pandas as pd
import os
import glob

# %%
od_tenders = pd.read_csv(r'/Users/saurabhlevin/Deployment/flood-data-ecosystem-Odisha/Sources/TENDERS/data/odisha_all_tenders.csv')
od_tenders = od_tenders.loc[od_tenders['Status'] == 'Accepted-AOC']
print(f"Number of accepted tenders: {len(od_tenders)}")
od_tenders
# Out:
# Number of accepted tenders: 13493
#                  Tender ID             tender_externalreference  \
# 2       2020_BPUTW_62754_1            TEQIP-III/2020/OD/bpuo/58
# 14        2020_OMC_59608_1                 NIT-5/OMC/Civil/2020
# 23      2018_CERWI_48091_2     Building Tender Online RWCSBP-45
# 25      2019_CERWI_53180_2          ONLINE-13-2018-19 (BRIDGES)
# 27      2020_CCEBA_59020_1  EE CKD NCB/05 /ORDRIPW-05 / 2019-20
# ...                    ...                                  ...
# 57046  2024_CERWI_100971_9            SE/RW/BDKII/TCN16/2023-24
# 57047   2023_DZPBR_85370_1  IFB-CDO-cum-EO,ZP,BGH,02 of 2022-23
# 57050   2023_DZPBR_85370_2  IFB-CDO-cum-EO,ZP,BGH,02 of 2022-23
# 57051   2023_DZPBR_85370_5  IFB-CDO-cum-EO,ZP,BGH,02 of 2022-23
# 57054   2023_DZPBR_85370_9  IFB-CDO-cum-EO,ZP,BGH,02 of 2022-23
#
#                                             tender_title  \
# 2                                        2x1 KW solar PV
# ...

# %%
od_tenders['Awarded Value'].str.replace(',','').astype(float).sum()
# Out:
# np.float64(160425643661.38892)

# %%
od_flood_tenders = pd.read_csv(r'/Users/saurabhlevin/Deployment/flood-data-ecosystem-Odisha/Sources/TENDERS/data/flood_tenders_all.csv')
od_flood_tenders = od_flood_tenders.loc[od_flood_tenders['Status'] == 'Accepted-AOC']
print(f"Number of accepted tenders: {len(od_flood_tenders)}")
od_flood_tenders
# Out:
# Number of accepted tenders: 2738
#                   Tender ID                          tender_externalreference  \
# 4        2019_CERWI_53180_2                       ONLINE-13-2018-19 (BRIDGES)
# 8        2021_CERWI_71552_5                             EE/RW/Jls- 07/2021-22
# 21       2021_EICCL_74577_1  Bid Identification No.S.E.E.C (RandB) 12/2021-22
# 27       2022_CEBBS_79393_1           Bid Identification No.SE-HID-02/2022-23
# 60       2022_CERWI_78672_2                         EE/RWELECT/SBP/03/2022-23
# ...                     ...                                               ...
# 12443   2024_ORULB_102004_8                                     JM-09/2023-24
# 12445  2024_CEMIB_100361_10                            SE-MID-PDP- 09/2023-24
# 12446  2024_ORULB_101402_69                              EO/RGP/08 of 2023-24
# 12451    2023_ORULB_98027_1                                   SNGM-22/2023-24
# 12457  2024_ORULB_102004_21                                     JM-09/2023-24
#
# ...

# %%
od_flood_tenders['Awarded Value'].str.replace(',','').astype(float).sum()
# Out:
# np.float64(55378594974.02461)
